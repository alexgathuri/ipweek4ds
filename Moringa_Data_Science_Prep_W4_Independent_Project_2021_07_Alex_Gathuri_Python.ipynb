# %% [markdown]
# 1.0 Importing libraries

# %%
# Let's import the pandas library
#
# OUR CODE GOES HERE
import pandas as pd
# as well as the Numpy library
import numpy as np

# %% [markdown]
# 1.1 Loading datasets

# %% [markdown]
# Telcom_datasets

# %%
# Saving the above dataframe as csv in the working directory
df = pd.read_csv (r'Autolib_dataset (2).csv')
df
# Out:
#                                  Address  Cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue M̩nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [5000 rows x 25 columns]

# %%
#Filtering only from the city of paris

paris =df[df['City']== 'Paris']

# %%
paris
# Out:
#                                  Address  Cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 3                 51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# 5                   8 Boulevard Voltaire     0  ...     7       2
# ...                                  ...   ...  ...   ...     ...
# 4992                     3 avenue d'Ivry     0  ...    23       1
# 4994                    15 rue de Rocroy     0  ...    20      49
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [2816 rows x 25 columns]

# %%
#removed 0 value of cars from new dataset
paris2= paris[paris['Bluecar counter']>0]
paris2
# Out:
#                                  Address  Cars  ...  hour  minute
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 3                 51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# 8                  34 avenue Jean Moulin     1  ...    22      58
# 9           41 boulevard de Rochechouart     6  ...    15       2
# ...                                  ...   ...  ...   ...     ...
# 4985     6 place du Pr̩sident Mithouard     2  ...     2      35
# 4988                        62 Rue Ramey     5  ...    11       0
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [1787 rows x 25 columns]

# %%
#popular time
paris2['hour'].value_counts()
# Out:
# 21    95
# 12    90
# 6     81
# 9     80
# 13    80
# 10    80
# 15    79
# 8     79
# 17    78
# 16    78
# 19    75
# 18    75
# 5     74
# 7     73
# 3     73
# 11    70
# 22    69
# 2     69
# 4     68
# 0     68
# 23    67
# 1     64
# 20    63
# 14    59
# Name: hour, dtype: int64

# %% [markdown]
# Popular hour for returning **cars**
